# %% [markdown]
# # Welcome — стартовый ноутбук для дата-сайентистов
#
# Пример использует стек из `requirements.txt`: numpy, pandas, matplotlib, seaborn, scikit-learn.
#
# Общая папка для датасетов, доступная всем пользователям: `/srv/shared`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

rng = np.random.default_rng(42)
df = pd.DataFrame({
    "x": rng.normal(size=200),
    "y": rng.normal(size=200),
    "group": rng.choice(["A", "B"], size=200),
})
df.head()

# %%
fig, ax = plt.subplots()
sns.scatterplot(data=df, x="x", y="y", hue="group", ax=ax)
ax.set_title("Пример визуализации")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X = df[["x", "y"]]
y = (df["group"] == "A").astype(int)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

model = LogisticRegression().fit(X_train, y_train)
print("Accuracy:", model.score(X_test, y_test))

# %% [markdown]
# ## Датасеты
#
# Положите общие csv/parquet файлы в `/srv/shared` (хостовая папка `./shared`),
# они будут доступны всем пользователям хаба на чтение и запись.
